# %% [markdown]
# # Módulo 4: Introdução ao Pandas e carga de dados
# # Exercício 3
#
#
# Faremos neste Notebook a conexão com API. São dois exercícios:
# 1) Ler API e fazer consultas;
# 2) Fazer função API, fazer consultas e salvar arquivo ".csv".

# %%
import pandas as pd
import requests
import os

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) municípios no estado do Rio de Janeiro
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
r = requests.get (url)
conexao = r.status_code

if conexao == 200:
    print('Conexão com API realizada com sucesso!')
else:
    print('Conexão com API falhou!')
# Out:
# Conexão com API realizada com sucesso!

# %%
data_json = r.json()
print(data_json)
# Out:
# {'items': [{'id_pleito': 12375, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001671/2011-00', 'data_protocolo': '2011-10-18T02:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Preservação e recuperação ambiental', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 451980000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '27/12/2011'}, {'id_pleito': 10562, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001228/2013-92', 'data_protocolo': '2013-10-22T02:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 500000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '27/12/2013'}, {'id_pleito': 13364, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.002059/2008-41', 'data_protocolo': '2009-05-14T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 211700000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '22/05/2009'}, {'id_pleito': 9050, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000893/2010-16', 'data_protocolo': '2011-06-03T03:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 259138332.31, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '04/07/2011'}, {'id_pleito': 22594, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': '00000.000000/2031-89', 'status': 'Arquivado por decurso de prazo', 'num_processo': '17944.000657/2016-95', 'data_protocolo': '2016-05-12T03:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 989210440, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '25/10/2016'}, {'id_pleito': 12410, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001680/2011-92', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 600000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '10/07/2012'}, {'id_pleito': 10606, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.001240/2009-11', 'data_protocolo': '2009-10-22T02:00:00Z', 'tipo_operacao': 'O ...

# %%
dados_rj = pd.DataFrame(data_json['items'])

# %%
dados_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0      12375           Estado  Rio de Janeiro        33  RJ
# 1      10562           Estado  Rio de Janeiro        33  RJ
# 2      13364           Estado  Rio de Janeiro        33  RJ
# 3       9050           Estado  Rio de Janeiro        33  RJ
# 4      22594           Estado  Rio de Janeiro        33  RJ
#
#                 num_pvl                                             status  \
# 0                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4  00000.000000/2031-89                     Arquivado por decurso de prazo
#
#            num_processo        data_protocolo  \
# 0  17944.001671/2011-00  2011-10-18T02:00:00Z
# 1  17944.001228/2013-92  2013-10-22T02:00:00Z
# 2  17944.002059/2008-41  2009-05-14T03:00:00Z
# 3  17944.000893/2010-16  2011-06-03T03:00:00Z
# 4  17944.000657/2016-95  2016-05-12T03:00:00Z
#
#                                        tipo_operacao  \
# 0  Operação contratual externa (com garantia da U...
# 1  Operação contratual externa (com garantia da U...
# 2  Operação contratual externa (com garantia da U...
# 3  Operação contratual interna (com garantia da U...
# 4  Operação contratual interna (com garantia da U...
#
#                             finalidade                           tipo_credor  \
# 0  Preservação e recuperação ambiental  Instituição Financeira Internacional
# 1                       Infraestrutura  Instituição Financeira Internacional
# 2                       Infraestrutura  Instituição Financeira Internacional
# 3                       Infraestrutura       Instituição Financeira Nacional
# 4                       Infraestrutura       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3                            Caixa Econômica Federal           Real
# 4  Banco Nacional de Desenvolvimento Econômico e ...           Real
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  4.519800e+08                 1                      0  27/12/2011
# 1  5.000000e+08                 1                      0  27/12/2013
# 2  2.117000e+08                 1                      0  22/05/2009
# 3  2.591383e+08                 1                      0  04/07/2011
# 4  9.892104e+08                 0                      0  25/10/2016

# %%
dados_rj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              52 non-null     int64
#  1   tipo_interessado       52 non-null     object
#  2   interessado            52 non-null     object
#  3   cod_ibge               52 non-null     int64
#  4   uf                     52 non-null     object
#  5   num_pvl                3 non-null      object
#  6   status                 52 non-null     object
#  7   num_processo           52 non-null     object
#  8   data_protocolo         52 non-null     object
#  9   tipo_operacao          52 non-null     object
#  10  finalidade             52 non-null     object
#  11  tipo_credor            52 non-null     object
#  12  credor                 52 non-null     object
#  13  moeda                  52 non-null     object
#  14  valor                  52 non-null     float64
#  15  pvl_assoc_divida       52 non-null     int64
#  16  pvl_contradado_credor  52 non-null     int64
#  17  data_status            52 non-null     object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 7.4+ KB

# %%
# 2) As três primeiras frequências dos "status"
dados_rj['status'].value_counts()[0:3]
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Name: count, dtype: int64

# %%
# 3) Criação da variável "ano_status" com o ano advindo da data

data = pd.DatetimeIndex(dados_rj['data_status'])
dados_rj['ano_status'] = data.year
dados_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0      12375           Estado  Rio de Janeiro        33  RJ
# 1      10562           Estado  Rio de Janeiro        33  RJ
# 2      13364           Estado  Rio de Janeiro        33  RJ
# 3       9050           Estado  Rio de Janeiro        33  RJ
# 4      22594           Estado  Rio de Janeiro        33  RJ
#
#                 num_pvl                                             status  \
# 0                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4  00000.000000/2031-89                     Arquivado por decurso de prazo
#
#            num_processo        data_protocolo  \
# 0  17944.001671/2011-00  2011-10-18T02:00:00Z
# 1  17944.001228/2013-92  2013-10-22T02:00:00Z
# 2  17944.002059/2008-41  2009-05-14T03:00:00Z
# 3  17944.000893/2010-16  2011-06-03T03:00:00Z
# 4  17944.000657/2016-95  2016-05-12T03:00:00Z
#
#                                        tipo_operacao  \
# 0  Operação contratual externa (com garantia da U...
# 1  Operação contratual externa (com garantia da U...
# 2  Operação contratual externa (com garantia da U...
# 3  Operação contratual interna (com garantia da U...
# 4  Operação contratual interna (com garantia da U...
#
#                             finalidade                           tipo_credor  \
# 0  Preservação e recuperação ambiental  Instituição Financeira Internacional
# 1                       Infraestrutura  Instituição Financeira Internacional
# 2                       Infraestrutura  Instituição Financeira Internacional
# 3                       Infraestrutura       Instituição Financeira Nacional
# 4                       Infraestrutura       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3                            Caixa Econômica Federal           Real
# 4  Banco Nacional de Desenvolvimento Econômico e ...           Real
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status  \
# 0  4.519800e+08                 1                      0  27/12/2011
# 1  5.000000e+08                 1                      0  27/12/2013
# 2  2.117000e+08                 1                      0  22/05/2009
# 3  2.591383e+08                 1                      0  04/07/2011
# 4  9.892104e+08                 0                      0  25/10/2016
#
#    ano_status
# 0        2011
# 1        2013
# 2        2009
# 3        2011
# 4        2016

# %%
# 4) Frequência por "ano_status" 
dados_rj['ano_status'].value_counts()
# Out:
# ano_status
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2016     4
# 2014     4
# 2002     4
# 2010     3
# 2006     2
# 2008     2
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Função com parâmetros "UF" e "tipo_interessado"

def filtro_api(uf, tipo_interessado):
    url = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}'
    
    try:
        response = requests.get(url)
        r = requests.get (url)
        conexao = r.status_code

        response = requests.get(url)
        response.raise_for_status()  
        data = response.json()  
        df = pd.DataFrame(data['items'])  

        return df
    
    except requests.exceptions.RequestException as e:
        print(f"Ocorreu um erro: {e}")
        
        return None

# %%
# 2) Solicitações do estado de Minas Gerais

dados = filtro_api('MG', 'Estado')
dados_mg = pd.DataFrame(dados)
dados_mg.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 0      11132           Estado  Minas Gerais        31  MG    None
# 1      13275           Estado  Minas Gerais        31  MG    None
# 2      11571           Estado  Minas Gerais        31  MG    None
# 3       7023           Estado  Minas Gerais        31  MG    None
# 4      13618           Estado  Minas Gerais        31  MG    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001368/2009-84
# 1                                 Arquivado a pedido  17944.002000/2013-10
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.001479/2009-91
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000480/2012-01
# 4  Encaminhado à PGFN com manifestação técnica fa...  19405.000037/2006-15
#
#          data_protocolo                                      tipo_operacao  \
# 0  2009-11-20T02:00:00Z  Operação contratual externa (com garantia da U...
# 1  2014-04-17T03:00:00Z  Operação contratual interna (com garantia da U...
# 2  2010-03-26T03:00:00Z  Operação contratual externa (com garantia da U...
# 3  2012-10-11T03:00:00Z  Operação contratual externa (com garantia da U...
# 4  2009-02-26T03:00:00Z  Operação contratual externa (com garantia da U...
#
#                                           finalidade  \
# 0                                     Infraestrutura
# 1                                     Infraestrutura
# 2                                     Multissetorial
# 3  Reestruturação e recomposição do principal de ...
# 4                                     Multissetorial
#
#                             tipo_credor  \
# 0  Instituição Financeira Internacional
# 1       Instituição Financeira Nacional
# 2  Instituição Financeira Internacional
# 3  Instituição Financeira Internacional
# 4  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3                Agência Francesa de Desenvolvimento           Euro
# 4            Banco Interamericano de Desenvolvimento  Dólar dos EUA
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  137000000.0                 1                      0  26/11/2009
# 1  600000000.0                 0                      0  24/04/2014
# 2  461000000.0                 1                      0  01/04/2010
# 3  300000000.0                 1                      0  16/10/2012
# 4   10000000.0                 1                      0  12/03/2009

# %%
num_arquivado = dados_mg[dados_mg['status']=='Arquivado por decurso de prazo'].value_counts()
num_arquivado
# Out:
# id_pleito  tipo_interessado  interessado   cod_ibge  uf  num_pvl               status                          num_processo          data_protocolo        tipo_operacao                finalidade  tipo_credor                      credor                                                moeda  valor      pvl_assoc_divida  pvl_contradado_credor  data_status
# 20534      Estado            Minas Gerais  31        MG  00000.000000/2017-69  Arquivado por decurso de prazo  17944.001113/2015-60  2017-07-26T03:00:00Z  Operação contratual interna  PMAE        Instituição Financeira Nacional  Banco Nacional de Desenvolvimento Econômico e Social  Real   7668000.0  0                 0                      16/03/2018     1
# Name: count, dtype: int64

# %%
arquivado = dados_mg[dados_mg['status']=='Arquivado por decurso de prazo']
arquivado
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 7      20534           Estado  Minas Gerais        31  MG
#
#                 num_pvl                          status          num_processo  \
# 7  00000.000000/2017-69  Arquivado por decurso de prazo  17944.001113/2015-60
#
#          data_protocolo                tipo_operacao finalidade  \
# 7  2017-07-26T03:00:00Z  Operação contratual interna       PMAE
#
#                        tipo_credor  \
# 7  Instituição Financeira Nacional
#
#                                               credor moeda      valor  \
# 7  Banco Nacional de Desenvolvimento Econômico e ...  Real  7668000.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 7                 0                      0  16/03/2018

# %%
# 3) Município da Bahia com mais solicitações 'deferidas'

dados = filtro_api('BA', 'Estado')
dados_ba = pd.DataFrame(dados)
dados_ba.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl  \
# 0      10528           Estado       Bahia        29  BA    None
# 1      18551           Estado       Bahia        29  BA    None
# 2      18575           Estado       Bahia        29  BA    None
# 3      18579           Estado       Bahia        29  BA    None
# 4      18587           Estado       Bahia        29  BA    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001222/2010-72
# 1                                           Deferido  19407.000049/2002-98
# 2                                           Deferido  19407.000055/2002-45
# 3                                           Deferido  19407.000056/2002-90
# 4                                           Deferido  19407.000058/2002-89
#
#          data_protocolo                                      tipo_operacao  \
# 0  2010-12-20T02:00:00Z  Operação contratual interna (com garantia da U...
# 1  2002-06-21T03:00:00Z                        Operação contratual interna
# 2  2002-06-17T03:00:00Z                        Operação contratual interna
# 3  2002-06-19T03:00:00Z                        Operação contratual interna
# 4  2002-06-17T03:00:00Z                        Operação contratual interna
#
#             finalidade                      tipo_credor  \
# 0  PAC - Copa Estádios  Instituição Financeira Nacional
# 1    Saneamento básico  Instituição Financeira Nacional
# 2       Infraestrutura  Instituição Financeira Nacional
# 3    Saneamento básico  Instituição Financeira Nacional
# 4    Saneamento básico  Instituição Financeira Nacional
#
#                                               credor moeda         valor  \
# 0  Banco Nacional de Desenvolvimento Econômico e ...  Real  3.236290e+08
# 1                            Caixa Econômica Federal  Real  4.994000e+06
# 2                            Caixa Econômica Federal  Real  9.392073e+06
# 3                            Caixa Econômica Federal  Real  8.667000e+06
# 4                            Caixa Econômica Federal  Real  1.400868e+06
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 1                      0  28/12/2010
# 1                 1                      0  05/07/2002
# 2                 1                      0  05/07/2002
# 3                 1                      0  05/07/2002
# 4                 1                      0  08/07/2002

# %%
deferido = dados_ba[dados_ba['status']=='Deferido']['tipo_interessado'].value_counts()
deferido
# Out:
# tipo_interessado
# Estado    50
# Name: count, dtype: int64

# %%
deferido = dados_ba[dados_ba['status']=='Deferido']['tipo_interessado']
deferido
# Out:
# 1     Estado
# 2     Estado
# 3     Estado
# 4     Estado
# 5     Estado
# 6     Estado
# 7     Estado
# 9     Estado
# 10    Estado
# 11    Estado
# 14    Estado
# 15    Estado
# 16    Estado
# 18    Estado
# 19    Estado
# 20    Estado
# 21    Estado
# 22    Estado
# 24    Estado
# 25    Estado
# 26    Estado
# 28    Estado
# 29    Estado
# 30    Estado
# 31    Estado
# 33    Estado
# 39    Estado
# 41    Estado
# 42    Estado
# 43    Estado
# 47    Estado
# 48    Estado
# 49    Estado
# 50    Estado
# 51    Estado
# 52    Estado
# 53    Estado
# 55    Estado
# 56    Estado
# 62    Estado
# 68    Estado
# 69    Estado
# 73    Estado
# 74    Estado
# 75    Estado
# 76    Estado
# 77    Estado
# 79    Estado
# 80    Estado
# 82    Estado
# Name: tipo_interessado, dtype: object

# %%
# 4) Salvar arquivo .csv

interessado_estado = dados_ba[dados_ba['tipo_interessado']=='Estado']

file_name = 'solicitacoes_bahia_estado.csv'

if os.path.exists(file_name):
        print(f"O arquivo '{file_name}' já existe.")
else:
        import datetime
        timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
        file_name = f'solicitacoes_bahia_estado_{timestamp}.csv'

        interessado_estado.to_csv(file_name, index=False)
        print(f"Arquivo salvo como  '{file_name}'")
# Out:
# O arquivo 'solicitacoes_bahia_estado.csv' já existe.
